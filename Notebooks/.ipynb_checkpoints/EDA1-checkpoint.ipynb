# %%
import pandas as pd

# %%
outcomes_data = pd.read_csv('../raw_data/Unplanned_Hospital_Visits-Hospital.csv')

# %%
outcomes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67970 entries, 0 to 67969
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Facility ID                  67970 non-null  object
#  1   Facility Name                67970 non-null  object
#  2   Address                      67970 non-null  object
#  3   City                         67970 non-null  object
#  4   State                        67970 non-null  object
#  5   ZIP Code                     67970 non-null  int64
#  6   County Name                  67970 non-null  object
#  7   Phone Number                 67970 non-null  object
#  8   Measure ID                   67970 non-null  object
#  9   Measure Name                 67970 non-null  object
#  10  Compared to National         67970 non-null  object
#  11  Denominator                  67970 non-null  object
#  12  Score                        67970 non-null  object
# ...

# %%
outcomes_data.head()
# Out:
#   Facility ID                    Facility Name                 Address  \
# 0       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number   Measure ID  \
# 0  DOTHAN    AL     36301     Houston  (334) 793-8701  EDAC_30_AMI
# 1  DOTHAN    AL     36301     Houston  (334) 793-8701   EDAC_30_HF
# 2  DOTHAN    AL     36301     Houston  (334) 793-8701   EDAC_30_PN
# 3  DOTHAN    AL     36301     Houston  (334) 793-8701        OP_32
# 4  DOTHAN    AL     36301     Houston  (334) 793-8701    OP_35_ADM
#
#                                         Measure Name  \
# 0     Hospital return days for heart attack patients
# ...

# %%
missing = pd.concat([outcomes_data.isnull().sum(), 100 * outcomes_data.isnull().mean()], axis=1)
missing.columns=["count", "%"]
missing.sort_values(by='count', ascending= False)
# Out:
#                              count          %
# Footnote                     39055  57.459173
# Facility ID                      0   0.000000
# Facility Name                    0   0.000000
# Start Date                       0   0.000000
# Number of Patients Returned      0   0.000000
# Number of Patients               0   0.000000
# Higher Estimate                  0   0.000000
# Lower Estimate                   0   0.000000
# Score                            0   0.000000
# Denominator                      0   0.000000
# Compared to National             0   0.000000
# Measure Name                     0   0.000000
# Measure ID                       0   0.000000
# Phone Number                     0   0.000000
# County Name                      0   0.000000
# ZIP Code                         0   0.000000
# State                            0   0.000000
# City                             0   0.000000
# Address                          0   0.000000
# ...

# %%
outcomes_data = outcomes_data.drop(['Address','ZIP Code','Phone Number', 'Compared to National', 'Footnote', 'Start Date','End Date'], axis=1)

# %%
outcomes_data.head()
# Out:
#   Facility ID                    Facility Name    City State County Name  \
# 0       10001  SOUTHEAST HEALTH MEDICAL CENTER  DOTHAN    AL     Houston
# 1       10001  SOUTHEAST HEALTH MEDICAL CENTER  DOTHAN    AL     Houston
# 2       10001  SOUTHEAST HEALTH MEDICAL CENTER  DOTHAN    AL     Houston
# 3       10001  SOUTHEAST HEALTH MEDICAL CENTER  DOTHAN    AL     Houston
# 4       10001  SOUTHEAST HEALTH MEDICAL CENTER  DOTHAN    AL     Houston
#
#     Measure ID                                       Measure Name Denominator  \
# 0  EDAC_30_AMI     Hospital return days for heart attack patients         424
# 1   EDAC_30_HF    Hospital return days for heart failure patients         904
# 2   EDAC_30_PN        Hospital return days for pneumonia patients         503
# 3        OP_32  Rate of unplanned hospital visits after colono...         511
# 4    OP_35_ADM  Rate of inpatient admissions for patients rece...         192
#
# ...

# %%
outcomes_data2 = outcomes_data[outcomes_data["Measure ID"].str.contains("READM_30_HOSP_WIDE")==True]

# %%
outcomes_data2.head()
# Out:
#    Facility ID                    Facility Name      City State County Name  \
# 12       10001  SOUTHEAST HEALTH MEDICAL CENTER    DOTHAN    AL     Houston
# 26       10005         MARSHALL MEDICAL CENTERS      BOAZ    AL    Marshall
# 40       10006     NORTH ALABAMA MEDICAL CENTER  FLORENCE    AL  Lauderdale
# 54       10007         MIZELL MEMORIAL HOSPITAL       OPP    AL   Covington
# 68       10008      CRENSHAW COMMUNITY HOSPITAL   LUVERNE    AL    Crenshaw
#
#             Measure ID                                       Measure Name  \
# 12  READM_30_HOSP_WIDE  Rate of readmission after discharge from hospi...
# 26  READM_30_HOSP_WIDE  Rate of readmission after discharge from hospi...
# 40  READM_30_HOSP_WIDE  Rate of readmission after discharge from hospi...
# 54  READM_30_HOSP_WIDE  Rate of readmission after discharge from hospi...
# 68  READM_30_HOSP_WIDE  Rate of readmission after discharge from hospi...
#
# ...

# %%
outcomes_data2 = outcomes_data2[outcomes_data2["Denominator"].str.contains("Not Available")==False]

# %%
outcomes_data2.head(50)
# Out:
#     Facility ID                              Facility Name            City  \
# 12        10001            SOUTHEAST HEALTH MEDICAL CENTER          DOTHAN
# 26        10005                   MARSHALL MEDICAL CENTERS            BOAZ
# 40        10006               NORTH ALABAMA MEDICAL CENTER        FLORENCE
# 54        10007                   MIZELL MEMORIAL HOSPITAL             OPP
# 68        10008                CRENSHAW COMMUNITY HOSPITAL         LUVERNE
# 82        10011                         ST. VINCENT'S EAST      BIRMINGHAM
# 96        10012             DEKALB REGIONAL MEDICAL CENTER      FORT PAYNE
# 110       10016              SHELBY BAPTIST MEDICAL CENTER       ALABASTER
# 138       10019                      HELEN KELLER HOSPITAL       SHEFFIELD
# 152       10021                        DALE MEDICAL CENTER           OZARK
# 166       10022                    CHEROKEE MEDICAL CENTER          CENTRE
# ...

# %%
outcomes_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4117 entries, 12 to 67772
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Facility ID                  4117 non-null   object
#  1   Facility Name                4117 non-null   object
#  2   City                         4117 non-null   object
#  3   State                        4117 non-null   object
#  4   County Name                  4117 non-null   object
#  5   Measure ID                   4117 non-null   object
#  6   Measure Name                 4117 non-null   object
#  7   Denominator                  4117 non-null   float64
#  8   Score                        4117 non-null   object
#  9   Lower Estimate               4117 non-null   object
#  10  Higher Estimate              4117 non-null   object
#  11  Number of Patients           4117 non-null   object
#  12  Number of Patients Returned  4117 non-null   object
# ...

# %%
outcomes_data2['Denominator'] = outcomes_data2['Denominator'].astype(float, errors = 'raise')

# %%
outcomes_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4117 entries, 12 to 67772
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Facility ID                  4117 non-null   object
#  1   Facility Name                4117 non-null   object
#  2   City                         4117 non-null   object
#  3   State                        4117 non-null   object
#  4   County Name                  4117 non-null   object
#  5   Measure ID                   4117 non-null   object
#  6   Measure Name                 4117 non-null   object
#  7   Denominator                  4117 non-null   float64
#  8   Score                        4117 non-null   object
#  9   Lower Estimate               4117 non-null   object
#  10  Higher Estimate              4117 non-null   object
#  11  Number of Patients           4117 non-null   object
#  12  Number of Patients Returned  4117 non-null   object
# ...

# %%
outcomes_data2.shape
# Out:
# (4117, 13)

# %%
outcomes_data2.Denominator[outcomes_data2.Denominator > 1000].describe()
# Out:
# count     995.000000
# mean     1865.025126
# std       931.046091
# min      1001.000000
# 25%      1230.500000
# 50%      1581.000000
# 75%      2175.000000
# max      9065.000000
# Name: Denominator, dtype: float64

# %%
outcomes_data2.Denominator[outcomes_data2.Denominator > 100].describe()
# Out:
# count    3050.000000
# mean      883.858033
# std       890.952534
# min       101.000000
# 25%       242.000000
# 50%       593.500000
# 75%      1206.750000
# max      9065.000000
# Name: Denominator, dtype: float64

# %%
outcomes_data3 = outcomes_data2[outcomes_data2.Denominator >= 1000]

# %%
outcomes_data3.shape
# Out:
# (996, 13)

# %%
outcomes_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 996 entries, 12 to 67730
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Facility ID                  996 non-null    object
#  1   Facility Name                996 non-null    object
#  2   City                         996 non-null    object
#  3   State                        996 non-null    object
#  4   County Name                  996 non-null    object
#  5   Measure ID                   996 non-null    object
#  6   Measure Name                 996 non-null    object
#  7   Denominator                  996 non-null    float64
#  8   Score                        996 non-null    object
#  9   Lower Estimate               996 non-null    object
#  10  Higher Estimate              996 non-null    object
#  11  Number of Patients           996 non-null    object
#  12  Number of Patients Returned  996 non-null    object
# ...

# %%
outcomes_data3['Number of Patients'].value_counts().head()
# Out:
# Not Applicable    996
# Name: Number of Patients, dtype: int64

# %%
outcomes_data3['Number of Patients Returned'].value_counts().head()
# Out:
# Not Applicable    996
# Name: Number of Patients Returned, dtype: int64

# %%
outcomes_data3.drop(['Number of Patients','Number of Patients Returned'], axis=1)
# Out:
#       Facility ID                                     Facility Name  \
# 12          10001                   SOUTHEAST HEALTH MEDICAL CENTER
# 40          10006                      NORTH ALABAMA MEDICAL CENTER
# 180         10023                      BAPTIST MEDICAL CENTER SOUTH
# 194         10024                     JACKSON HOSPITAL & CLINIC INC
# 208         10029             THE EAST ALABAMA HEALTHCARE AUTHORITY
# ...           ...                                               ...
# 66666      530014                  CHEYENNE REGIONAL MEDICAL CENTER
# 67128      670025   BAYLOR SCOTT & WHITE THE HEART HOSPITAL - PLANO
# 67156      670034  BAYLOR SCOTT & WHITE MEDICAL CENTER - ROUND ROCK
# 67268      670055                     METHODIST HOSPITAL  STONE OAK
# 67730      670122          HOUSTON METHODIST THE WOODLANDS HOSPITAL
#
#                 City State County Name          Measure ID  \
# 12            DOTHAN    AL     Houston  READM_30_HOSP_WIDE
# ...
